# %% [markdown]
# # 파생변수

# %%
from hossam import load_data
import numpy as np

# %% [markdown]
# ### 파생변수 추가하기

# %%
# 컬럼 연산을 통한 새로운 컬럼 추가
origin= load_data('grade')
origin
df1 = origin.copy()
df1['직접합계'] = df1['국어'] + df1['영어'] + df1['수학'] + df1['과학']
df1
# Out:
# [data] https://data.hossam.kr/data/common/grade.xlsx
# [desc] 어느 학급의 과목별 점수를 조사한 가상의 데이터
#
# field    description
# -------  -------------
# 이름     index
# 학년     int
# 성별     str
# 국어     int
# 영어     int
# 수학     int
# 과학     int
#     학년  성별  국어   영어  수학  과학  직접합계
# 이름
# 철수   1  남자  98   77  88  64   327
# 영희   2  여자  88  120  62  72   342
# 민철   1  남자  92   70  83  79   324
# 수현   3  여자  63   60  31  71   225
# 호영   4  남자  75   50  90  88   303
# 영호   4  남자  80   88  91  72   331
# 용식   2  남자  82   88  79  90   339
# 나영   1  여자  90   92  81  95   358
# 석영   1  남자  91   90  89  80   350

# %%
# 기술통계 관련 함수 사용한 파생변수 
# 컬럼 이름에 대한 슬라이싱 접근

df2 = origin.copy()
df2['합계'] = df2[df2.columns[2:6]].sum(axis=1)
df2
# Out:
#     학년  성별  국어   영어  수학  과학   합계
# 이름
# 철수   1  남자  98   77  88  64  327
# 영희   2  여자  88  120  62  72  342
# 민철   1  남자  92   70  83  79  324
# 수현   3  여자  63   60  31  71  225
# 호영   4  남자  75   50  90  88  303
# 영호   4  남자  80   88  91  72  331
# 용식   2  남자  82   88  79  90  339
# 나영   1  여자  90   92  81  95  358
# 석영   1  남자  91   90  89  80  350

# %%
# 인덱스 기반 슬라이싱하여 합계 변수 추가

df3 = origin.copy()
df3['합계'] = df3.iloc[:, 2:].sum(axis=1)
df3
# Out:
#     학년  성별  국어   영어  수학  과학   합계
# 이름
# 철수   1  남자  98   77  88  64  327
# 영희   2  여자  88  120  62  72  342
# 민철   1  남자  92   70  83  79  324
# 수현   3  여자  63   60  31  71  225
# 호영   4  남자  75   50  90  88  303
# 영호   4  남자  80   88  91  72  331
# 용식   2  남자  82   88  79  90  339
# 나영   1  여자  90   92  81  95  358
# 석영   1  남자  91   90  89  80  350

# %%
# 나머지 기술통계값 추가

df3['평균'] = df3.iloc[:, 2:6].mean(axis = 1)
df3['최대값'] = df3.iloc[:, 2:6].max(axis = 1)
df3['최소값'] = df3.iloc[:, 2:6].min(axis = 1)
df3['분산'] = df3.iloc[:, 2:6].var(axis = 1)
df3['표준편차'] = df3.iloc[:, 2:6].std(axis = 1)
df3
# Out:
#     학년  성별  국어   영어  수학  과학   합계     평균  최대값  최소값          분산       표준편차
# 이름
# 철수   1  남자  98   77  88  64  327  81.75   98   64  213.583333  14.614491
# 영희   2  여자  88  120  62  72  342  85.50  120   62  643.666667  25.370587
# 민철   1  남자  92   70  83  79  324  81.00   92   70   83.333333   9.128709
# 수현   3  여자  63   60  31  71  225  56.25   71   31  304.916667  17.461863
# 호영   4  남자  75   50  90  88  303  75.75   90   50  338.916667  18.409689
# 영호   4  남자  80   88  91  72  331  82.75   91   72   72.916667   8.539126
# 용식   2  남자  82   88  79  90  339  84.75   90   79   26.250000   5.123475
# 나영   1  여자  90   92  81  95  358  89.50   95   81   36.333333   6.027714
# 석영   1  남자  91   90  89  80  350  87.50   91   80   25.666667   5.066228

# %% [markdown]
# ### 조건별 파생 변수
# ## if~else(Where)

# %%
df4 = origin.copy()
df4['합계'] = df4.iloc[:, 2:6].sum(axis=1)
df4['평균'] = df4.iloc[:, 2:6].mean(axis=1)
df4
# Out:
#     학년  성별  국어   영어  수학  과학   합계     평균
# 이름
# 철수   1  남자  98   77  88  64  327  81.75
# 영희   2  여자  88  120  62  72  342  85.50
# 민철   1  남자  92   70  83  79  324  81.00
# 수현   3  여자  63   60  31  71  225  56.25
# 호영   4  남자  75   50  90  88  303  75.75
# 영호   4  남자  80   88  91  72  331  82.75
# 용식   2  남자  82   88  79  90  339  84.75
# 나영   1  여자  90   92  81  95  358  89.50
# 석영   1  남자  91   90  89  80  350  87.50

# %%
# Numpy의 where 함수 사용한 조건부 파생 변수

df4['결과1'] = np.where(df4['평균'] >= 80, '합격','불합격')
df4
# Out:
#     학년  성별  국어   영어  수학  과학   합계     평균  결과1
# 이름
# 철수   1  남자  98   77  88  64  327  81.75   합격
# 영희   2  여자  88  120  62  72  342  85.50   합격
# 민철   1  남자  92   70  83  79  324  81.00   합격
# 수현   3  여자  63   60  31  71  225  56.25  불합격
# 호영   4  남자  75   50  90  88  303  75.75  불합격
# 영호   4  남자  80   88  91  72  331  82.75   합격
# 용식   2  남자  82   88  79  90  339  84.75   합격
# 나영   1  여자  90   92  81  95  358  89.50   합격
# 석영   1  남자  91   90  89  80  350  87.50   합격

# %%
# 표현식 사용한 평균값에 따른 조건부 파생변수
df4['결과2'] = '불합격'
df4.loc[df4['평균'] >=80, '결과2'] = '합격'
df4
# Out:
#     학년  성별  국어   영어  수학  과학   합계     평균  결과1  결과2
# 이름
# 철수   1  남자  98   77  88  64  327  81.75   합격   합격
# 영희   2  여자  88  120  62  72  342  85.50   합격   합격
# 민철   1  남자  92   70  83  79  324  81.00   합격   합격
# 수현   3  여자  63   60  31  71  225  56.25  불합격  불합격
# 호영   4  남자  75   50  90  88  303  75.75  불합격  불합격
# 영호   4  남자  80   88  91  72  331  82.75   합격   합격
# 용식   2  남자  82   88  79  90  339  84.75   합격   합격
# 나영   1  여자  90   92  81  95  358  89.50   합격   합격
# 석영   1  남자  91   90  89  80  350  87.50   합격   합격

# %% [markdown]
# ### 경우의 수에 따른 조건값
# ### elif

# %%
# Select 함수 사용

conditions = [ (df4['평균'] >= 90),
               (df4['평균'] >= 80),
               (df4['평균'] >= 70)
]
value = ['A','B','C']

df4['학점1'] =np.select(conditions, value, default ='F')
df4
# Out:
#     학년  성별  국어   영어  수학  과학   합계     평균  결과1  결과2 학점1
# 이름
# 철수   1  남자  98   77  88  64  327  81.75   합격   합격   B
# 영희   2  여자  88  120  62  72  342  85.50   합격   합격   B
# 민철   1  남자  92   70  83  79  324  81.00   합격   합격   B
# 수현   3  여자  63   60  31  71  225  56.25  불합격  불합격   F
# 호영   4  남자  75   50  90  88  303  75.75  불합격  불합격   C
# 영호   4  남자  80   88  91  72  331  82.75   합격   합격   B
# 용식   2  남자  82   88  79  90  339  84.75   합격   합격   B
# 나영   1  여자  90   92  81  95  358  89.50   합격   합격   B
# 석영   1  남자  91   90  89  80  350  87.50   합격   합격   B

# %%
# 사용자 함수 정의하기

def getScore(x):
    if x>= 90:
        score = 'A'
    elif x>= 80:
        score = 'B'
    elif x>= 70:
        score = 'C'
    else:
        score = 'F'
    return score

# %%
# 파생변수 추가하기(사용자 함수 이용하여)

df4['학점2'] = df4['평균'].apply(getScore)
df4
# Out:
#     학년  성별  국어   영어  수학  과학   합계     평균  결과1  결과2 학점1 학점2
# 이름
# 철수   1  남자  98   77  88  64  327  81.75   합격   합격   B   B
# 영희   2  여자  88  120  62  72  342  85.50   합격   합격   B   B
# 민철   1  남자  92   70  83  79  324  81.00   합격   합격   B   B
# 수현   3  여자  63   60  31  71  225  56.25  불합격  불합격   F   F
# 호영   4  남자  75   50  90  88  303  75.75  불합격  불합격   C   C
# 영호   4  남자  80   88  91  72  331  82.75   합격   합격   B   B
# 용식   2  남자  82   88  79  90  339  84.75   합격   합격   B   B
# 나영   1  여자  90   92  81  95  358  89.50   합격   합격   B   B
# 석영   1  남자  91   90  89  80  350  87.50   합격   합격   B   B

# %%
# 람다식으로 적용하기

df4['학점3'] = df4['평균'].apply(
    lambda x: {10: 'A', 9:'A', 8:'B', 7:'C'}.get(x//10, 'F')
)
df4
# Out:
#     학년  성별  국어   영어  수학  과학   합계     평균  결과1  결과2 학점1 학점2 학점3
# 이름
# 철수   1  남자  98   77  88  64  327  81.75   합격   합격   B   B   B
# 영희   2  여자  88  120  62  72  342  85.50   합격   합격   B   B   B
# 민철   1  남자  92   70  83  79  324  81.00   합격   합격   B   B   B
# 수현   3  여자  63   60  31  71  225  56.25  불합격  불합격   F   F   F
# 호영   4  남자  75   50  90  88  303  75.75  불합격  불합격   C   C   C
# 영호   4  남자  80   88  91  72  331  82.75   합격   합격   B   B   B
# 용식   2  남자  82   88  79  90  339  84.75   합격   합격   B   B   B
# 나영   1  여자  90   92  81  95  358  89.50   합격   합격   B   B   B
# 석영   1  남자  91   90  89  80  350  87.50   합격   합격   B   B   B

# %%
# map() 함수 사용
# 연산 안되고, 값이 완전히 일치하는 경우에만 사용

df4['성별코드'] = df4['성별'].map({'남자': 'M', '여자': 'F'})
df4
# Out:
#     학년  성별  국어   영어  수학  과학   합계     평균  결과1  결과2 학점1 학점2 학점3 성별코드
# 이름
# 철수   1  남자  98   77  88  64  327  81.75   합격   합격   B   B   B    M
# 영희   2  여자  88  120  62  72  342  85.50   합격   합격   B   B   B    F
# 민철   1  남자  92   70  83  79  324  81.00   합격   합격   B   B   B    M
# 수현   3  여자  63   60  31  71  225  56.25  불합격  불합격   F   F   F    F
# 호영   4  남자  75   50  90  88  303  75.75  불합격  불합격   C   C   C    M
# 영호   4  남자  80   88  91  72  331  82.75   합격   합격   B   B   B    M
# 용식   2  남자  82   88  79  90  339  84.75   합격   합격   B   B   B    M
# 나영   1  여자  90   92  81  95  358  89.50   합격   합격   B   B   B    F
# 석영   1  남자  91   90  89  80  350  87.50   합격   합격   B   B   B    M

# %% [markdown]
# ### 연습문제

# %%
origin = load_data('online_shop_sales')
origin
# Out:
# [data] https://data.hossam.kr/data/lab05/online_shop_sales.xlsx
# [desc] 우수 고객을 찾아라! - 영업 데이터 분석 챌린지
#
# field      description
# ---------  ----------------
# OrderID    주문번호(인덱스)
# UserID     고객아이디
# Product    상품
# Price      가격
# Quantity   주문수량
# OrderDate  주문일
#          UserID          Product  Price  Quantity  OrderDate
# OrderID
# 1          1001           Laptop   1200         1 2024-10-01
# 2          1002            Mouse     25         2 2024-10-01
# 3          1001         Keyboard     75         1 2024-10-02
# 4          1003          Monitor    300         1 2024-10-03
# 5          1002           Webcam     50         1 2024-10-04
# 6          1003       HDMI Cable     15         3 2024-10-05
# 7          1001          USB Hub     30         2 2024-10-06
# 8          1004           Laptop   1300         1 2024-10-07
# 9          1002            Mouse     25         1 2024-10-08
# 10         1003          Monitor    300         2 2024-10-09
# ...

# %%
df1 = origin.drop(columns = ['OrderDate', 'Product'])
df1
# Out:
#          UserID  Price  Quantity
# OrderID
# 1          1001   1200         1
# 2          1002     25         2
# 3          1001     75         1
# 4          1003    300         1
# 5          1002     50         1
# 6          1003     15         3
# 7          1001     30         2
# 8          1004   1300         1
# 9          1002     25         1
# 10         1003    300         2
# 11         1001    150         1
# 12         1004    250         1
# 13         1002     80         1
# 14         1003     55         1
# 15         1001     28         1

# %%
df2 = df1.copy()
df2['Total'] = df2['Price'] * df2['Quantity'] 
df2 = df2.filter(['UserID','Total']).groupby('UserID').sum()
df2
# Out:
#         Total
# UserID
# 1001     1513
# 1002      205
# 1003     1000
# 1004     1550

# %%
df2.sort_values('Total', ascending = False).head(2)
# Out:
#         Total
# UserID
# 1004     1550
# 1001     1513
